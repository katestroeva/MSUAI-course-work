# %%
# !pip install git+https://github.com/kjappelbaum/gptchem.git
# Out:
# Collecting git+https://github.com/kjappelbaum/gptchem.git
#   Cloning https://github.com/kjappelbaum/gptchem.git to /tmp/pip-req-build-_qe2mra0
#   Running command git clone --filter=blob:none --quiet https://github.com/kjappelbaum/gptchem.git /tmp/pip-req-build-_qe2mra0
#   Resolved https://github.com/kjappelbaum/gptchem.git to commit 615339fd3520edfd03292690a339554d1f27f171
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting loguru (from gptchem==0.0.5.dev0)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (from gptchem==0.0.5.dev0) (1.52.2)
# Collecting fire (from gptchem==0.0.5.dev0)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fastcore in /usr/local/lib/python3.10/dist-packages (from gptchem==0.0.5.dev0) (1.7.19)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from gptchem==0.0.5.dev0) (4.12.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from gptchem==0.0.5.dev0) (1.5.2)
# Collecting pystow (from gptchem==0.0.5.dev0)
#   Downloading pystow-0.5.6-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from gptchem==0.0.5.dev0) (2.2.2)
# Collecting selfies (from gptchem==0.0.5.dev0)
#   Downloading selfies-2.1.2-py3-none-any.whl.metadata (14 kB)
# Collecting rdkit (from gptchem==0.0.5.dev0)
#   Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from gptchem==0.0.5.dev0) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore->gptchem==0.0.5.dev0) (24.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->gptchem==0.0.5.dev0) (2.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->gptchem==0.0.5.dev0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai->gptchem==0.0.5.dev0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai->gptchem==0.0.5.dev0) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai->gptchem==0.0.5.dev0) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai->gptchem==0.0.5.dev0) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->gptchem==0.0.5.dev0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai->gptchem==0.0.5.dev0) (4.66.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->gptchem==0.0.5.dev0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->gptchem==0.0.5.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->gptchem==0.0.5.dev0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->gptchem==0.0.5.dev0) (2024.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from pystow->gptchem==0.0.5.dev0) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pystow->gptchem==0.0.5.dev0) (2.32.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit->gptchem==0.0.5.dev0) (10.4.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gptchem==0.0.5.dev0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gptchem==0.0.5.dev0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gptchem==0.0.5.dev0) (3.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->gptchem==0.0.5.dev0) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->gptchem==0.0.5.dev0) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->gptchem==0.0.5.dev0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->gptchem==0.0.5.dev0) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->gptchem==0.0.5.dev0) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->gptchem==0.0.5.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->gptchem==0.0.5.dev0) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->gptchem==0.0.5.dev0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pystow->gptchem==0.0.5.dev0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pystow->gptchem==0.0.5.dev0) (2.2.3)
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.8 MB/s eta 0:00:00
# Downloading pystow-0.5.6-py3-none-any.whl (32 kB)
# Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 50.5 MB/s eta 0:00:00
# Downloading selfies-2.1.2-py3-none-any.whl (35 kB)
# Building wheels for collected packages: gptchem, fire
#   Building wheel for gptchem (pyproject.toml) ... done
#   Created wheel for gptchem: filename=gptchem-0.0.5.dev0-py3-none-any.whl size=64395 sha256=02b5219815a2579de13fb914ae051317eeb9c25eb64f60ee5c9c9c612e7f7fcf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jien0xml/wheels/57/ac/67/ab2ebf587197b3aa41cc568fbbfbf14f0693568e20a3b27762
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=54f213a3592aa56e2f081aea4af331cbfd502c8536c9067172b14b37af190644
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built gptchem fire
# Installing collected packages: selfies, rdkit, loguru, fire, pystow, gptchem
# Successfully installed fire-0.7.0 gptchem-0.0.5.dev0 loguru-0.7.2 pystow-0.5.6 rdkit-2024.3.5 selfies-2.1.2

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.52.2)
# Collecting openai
#   Downloading openai-1.54.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.54.1-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.3/389.3 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.52.2
#     Uninstalling openai-1.52.2:
#       Successfully uninstalled openai-1.52.2
# Successfully installed openai-1.54.1

# %%
import openai
print(openai.VERSION)
# Out:
# 1.52.2

# %%
import pandas as pd
hilic = pd.read_csv('HILIC_to_OHE_to_CNN')

# %%
hilic
# Out:
#                                                 smiles        rt
# 0    C1=CC=C2C(=C1)C(C(=O)N2)CC(=O)O               ...  2.019083
# 1    CC1C(NC(CN1)C2=CC=CC=C2)C                     ...  2.607950
# 2    C1CCC(C(C1)O)O                                ...  4.876550
# 3    C1CCC(=O)C(=O)C1                              ...  5.772267
# 4    CN1C2=C(NC1=O)N(C(=O)N(C2=O)C)C               ...  1.827733
# ..                                                 ...       ...
# 875  CC1CC2=C(CCC(=O)C2)C3C1C4CCC(C4(CC3)C)(C#C)O  ...  0.995283
# 876  C1=CC(=CC=C1C=CC2=CC(=CC(=C2)OC3C(C(C(C(O3)CO)...  4.640017
# 877  C(C1C(C(C(C(O1)OC2C(C(C(C(O2)COP(=O)(O)O)O)O)O...  9.717716
# 878  C1CC(=O)C(C=C1)(C(=O)OCC2=CC=CC=C2OC3C(C(C(C(O...  1.507783
# 879  CC(C)C12C(O1)C3C4(O3)C5(CCC6=C(C5CC7C4(C2O)O7)...  1.021050
#
# [880 rows x 2 columns]

# %%
from openai import OpenAI
apikey = ""
client = OpenAI(api_key=apikey)
client.fine_tuning.jobs.create(
  training_file="/content/HILIC_to_OHE_to_CNN",
  model="gpt-3.5-turbo"
)
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      71     try:
# ---> 72         yield
#      73     except Exception as exc:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     235         with map_httpcore_exceptions():
# --> 236             resp = self._pool.handle_request(req)
#     237
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     215             self._close_connections(closing)
# --> 216             raise exc from None
#     217
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     195                     # Send the request on the assigned connection.
# --> 196                     response = connection.handle_request(
#     197                         pool_request.request
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     100
# --> 101         return self._connection.handle_request(request)
#     102
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     142                     self._response_closed()
# --> 143             raise exc
#     144
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      92                 ) as trace:
# ---> 93                     self._send_request_headers(**kwargs)
#      94                 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http11.py in _send_request_headers(self, request)
#     150
# --> 151         with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     152             event = h11.Request(
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#     990         try:
# --> 991             response = self._client.send(
#     992                 request,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     925
# --> 926         response = self._send_handling_auth(
#     927             request,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     953             while True:
# --> 954                 response = self._send_handling_redirects(
#     955                     request,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     990
# --> 991             response = self._send_single_request(request)
#     992             try:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1026         with request_context(request=request):
# -> 1027             response = transport.handle_request(request)
#    1028
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     234         )
# --> 235         with map_httpcore_exceptions():
#     236             resp = self._pool.handle_request(req)
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      88         message = str(exc)
# ---> 89         raise mapped_exc(message) from exc
#      90
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# <ipython-input-1-2d6d6669c57c> in <cell line: 4>()
#       2 apikey = ""
#       3 client = OpenAI(api_key=apikey)
# ----> 4 client.fine_tuning.jobs.create(
#       5   training_file="/content/HILIC_to_OHE_to_CNN",
#       6   model="gpt-3.5-turbo"
#
# /usr/local/lib/python3.10/dist-packages/openai/resources/fine_tuning/jobs/jobs.py in create(self, model, training_file, hyperparameters, integrations, seed, suffix, validation_file, extra_headers, extra_query, extra_body, timeout)
#     142           timeout: Override the client-level default timeout for this request, in seconds
#     143         """
# --> 144         return self._post(
#     145             "/fine_tuning/jobs",
#     146             body=maybe_transform(
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277         )
# -> 1278         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1279
#    1280     def patch(
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     953             retries_taken = 0
#     954
# --> 955         return self._request(
#     956             cast_to=cast_to,
#     957             options=options,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1013
#    1014             if remaining_retries > 0:
# -> 1015                 return self._retry_request(
#    1016                     input_options,
#    1017                     cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091         time.sleep(timeout)
#    1092
# -> 1093         return self._request(
#    1094             options=options,
#    1095             cast_to=cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1013
#    1014             if remaining_retries > 0:
# -> 1015                 return self._retry_request(
#    1016                     input_options,
#    1017                     cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091         time.sleep(timeout)
#    1092
# -> 1093         return self._request(
#    1094             options=options,
#    1095             cast_to=cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1023
#    1024             log.debug("Raising connection error")
# -> 1025             raise APIConnectionError(request=request) from err
#    1026
#    1027         log.debug(
#
# APIConnectionError: Connection error.

# %%
from gptchem.gpt_classifier import GPTClassifier
from gptchem.tuner import Tuner

classifier = GPTClassifier(
    property_name="transition wavelength", # this is the property name we will use in the prompt template
    tuner=Tuner(n_epochs=8, learning_rate_multiplier=0.02, wandb_sync=False),
)

classifier.fit(["CC", "CDDFSS"], [0, 1])
predictions = classifier.predict(['CCCC', 'CCCCCCCC'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-1f2302d70296> in <cell line: 1>()
# ----> 1 from gptchem.gpt_classifier import GPTClassifier
#       2 from gptchem.tuner import Tuner
#       3
#       4 classifier = GPTClassifier(
#       5     property_name="transition wavelength", # this is the property name we will use in the prompt template
#
# /usr/local/lib/python3.10/dist-packages/gptchem/gpt_classifier.py in <module>
#      11 from gptchem.formatter import ClassificationFormatter
#      12 from gptchem.querier import Querier
# ---> 13 from gptchem.tuner import Tuner
#      14
#      15
#
# /usr/local/lib/python3.10/dist-packages/gptchem/tuner.py in <module>
#      11 from loguru import logger
#      12 from openai import FineTune
# ---> 13 from openai.cli import FineTune as FineTuneCli
#      14
#      15 from .types import PathType
#
# ImportError: cannot import name 'FineTune' from 'openai.cli' (/usr/local/lib/python3.10/dist-packages/openai/cli/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
